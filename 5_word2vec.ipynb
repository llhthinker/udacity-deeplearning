# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %% [markdown]
# ![skip-gram_CBOW](./pictures/skip-gram_CBOW.jpg)

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
print(collections.Counter(words[:100]))
print(collections.Counter(words[:100]).most_common(10))
# Out:
# Counter({'the': 9, 'a': 4, 'of': 4, 'used': 3, 'is': 3, 'as': 3, 'anarchism': 3, 'are': 2, 'term': 2, 'revolution': 2, 'and': 2, 'that': 2, 'to': 2, 'diggers': 1, 'unnecessary': 1, 'first': 1, 'taken': 1, 'differing': 1, 'including': 1, 'abolished': 1, 'pejorative': 1, 'rulers': 1, 'there': 1, 'class': 1, 'king': 1, 'culottes': 1, 'society': 1, 'abuse': 1, 'it': 1, 'label': 1, 'philosophy': 1, 'positive': 1, 'archons': 1, 'been': 1, 'word': 1, 'self': 1, 'english': 1, 'violent': 1, 'working': 1, 'describe': 1, 'chief': 1, 'without': 1, 'destroy': 1, 'french': 1, 'up': 1, 'has': 1, 'originated': 1, 'belief': 1, 'anarchists': 1, 'radicals': 1, 'defined': 1, 'be': 1, 'should': 1, 'ruler': 1, 'against': 1, 'greek': 1, 'whilst': 1, 'in': 1, 'act': 1, 'way': 1, 'early': 1, 'sans': 1, 'although': 1, 'derived': 1, 'by': 1, 'still': 1, 'organization': 1, 'any': 1, 'from': 1, 'political': 1, 'means': 1, 'also': 1})
# [('the', 9), ('a', 4), ('of', 4), ('used', 3), ('is', 3), ('as', 3), ('anarchism', 3), ('are', 2), ('term', 2), ('revolution', 2)]

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3135, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %% [markdown]
# - skip_window: 从当前input word的一侧（左边或右边）选取词的数量
# - num_skips: 从整个窗口中选取多少个不同的词作为我们的output word
#
# 下图为skip_window=2, num_skips=4的示例
# ![skip-gram](./pictures/skip-gram.png)

# %%
print(collections.deque(maxlen=5))
# Out:
# deque([], maxlen=5)

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]窗口大小
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'term', 'originated', 'a', 'term', 'originated', 'of', 'as']

# %% [markdown]
# Train a skip-gram model.

# %% [markdown]
# ![word2vec](./pictures/word2vec.png)

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  # embedding_lookup()用法: http://blog.csdn.net/u013041398/article/details/60955847
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  print(embed.shape)
  print(softmax_weights.shape)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# (128, 128)
# (50000, 128)

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.099648
# Nearest to can: euphrates, yod, participate, murakami, dared, novellas, brigham, grouse,
# Nearest to by: fainting, calabria, oldcastle, hermon, acute, merv, qed, otherwise,
# Nearest to are: diver, lusitani, greyhounds, pital, keanu, infertility, find, retitled,
# Nearest to eight: toy, alcohol, cmm, strengths, radius, kuti, corman, fielders,
# Nearest to american: todd, assemblages, undergraduate, offshoots, crashed, brick, fairy, hotline,
# Nearest to about: assimilated, rearranging, alhazred, saline, gimlin, saba, greens, nunnery,
# Nearest to as: incan, scam, bledsoe, incarceration, carriages, croesus, freeh, leander,
# Nearest to four: psychologist, fortune, meteorological, boom, cet, expanse, arlen, retroflex,
# Nearest to the: twinning, arsenic, paints, pancho, introspective, yasser, lithographic, ata,
# Nearest to its: caapi, elects, hematite, complete, dragoon, chen, worry, wahhabism,
# Nearest to during: column, avengers, negroponte, superstardom, madison, heretics, scouts, resigning,
# Nearest to so: arrange, dwight, valerian, celesta, downsizing, balzac, stationary, lumley,
# Nearest to not: bayesian, marry, dunkirk, objectionable, undergoes, kinks, grateful, rcaf,
# Nearest to world: roslin, demeter, associates, rationally, fit, numan, ossie, tapes,
# Nearest to if: entombed, premium, thousand, receptions, lans, webcomics, fraud, psychosis,
# Nearest to over: monuments, bikini, bridget, palate, espoo, pep, orientalist, dirk,
# Average loss at step 2000: 4.363723
# Average loss at step 4000: 3.863978
# Average loss at step 6000: 3.790934
# Average loss at step 8000: 3.684810
# Average loss at step 10000: 3.616454
# Nearest to can: may, would, must, could, manual, signatory, brigham, voted,
# Nearest to by: was, with, landform, during, from, including, on, courses,
# Nearest to are: were, is, have, sorrows, soong, was, exploratory, nearer,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to american: todd, fondly, unbundling, brutus, bounce, hotline, undergraduate, cannabis,
# Nearest to about: saline, rearranging, wladislaus, hides, quoting, vit, assimilated, implicit,
# Nearest to as: chandler, isuzu, voluntarily, establishes, mcgill, theologiae, gage, musket,
# Nearest to four: six, three, eight, five, seven, two, nine, zero,
# Nearest to the: its, a, his, this, extracted, their, genitive, an,
# Nearest to its: the, his, this, their, dragoon, hematite, comedic, uninhabited,
# Nearest to during: at, in, column, by, of, arithmetic, madison, scouts,
# Nearest to so: fools, await, arrange, lumley, trout, needed, customizable, heckman,
# Nearest to not: still, undergoes, to, it, also, bayesian, ida, they,
# Nearest to world: anthrax, u, separator, roslin, arthurian, flagellate, moderates, decides,
# Nearest to if: manchurian, perhaps, webcomics, payne, entombed, lans, discordians, harker,
# Nearest to over: arcadia, bikini, dirk, silesian, andreas, bend, hi, fledged,
# Average loss at step 12000: 3.604086
# Average loss at step 14000: 3.570279
# Average loss at step 16000: 3.413653
# Average loss at step 18000: 3.459632
# Average loss at step 20000: 3.536219
# Nearest to can: may, would, must, could, will, should, might, manual,
# Nearest to by: with, for, be, was, in, through, without, rosary,
# Nearest to are: were, is, have, was, sorrows, nearer, hydride, although,
# Nearest to eight: nine, seven, six, four, five, three, zero, two,
# Nearest to american: todd, dutch, austrian, atlantic, and, unbundling, canadian, transference,
# Nearest to about: rearranging, wladislaus, quoting, saline, affordable, assimilated, assassinate, scrutiny,
# Nearest to as: jess, fallacies, confirming, incarceration, latinus, establishes, flyby, mcgill,
# Nearest to four: seven, five, six, eight, three, nine, two, zero,
# Nearest to the: their, its, an, a, this, his, prepare, veritas,
# Nearest to its: their, his, the, orlogsflag, uninhabited, her, budget, bruckner,
# Nearest to during: at, in, column, after, jousting, within, ecumenical, arithmetic,
# Nearest to so: if, needed, possible, arrange, forrest, heckman, fools, later,
# Nearest to not: still, it, never, generally, also, they, ida, to,
# Nearest to world: anthrax, u, flagellate, arthurian, moderates, separator, roslin, selina,
# Nearest to if: when, perhaps, is, but, manchurian, so, bloody, discordians,
# Nearest to over: arcadia, around, dirk, hi, bridget, fledged, into, moira,
# Average loss at step 22000: 3.507185
# Average loss at step 24000: 3.485226
# Average loss at step 26000: 3.479976
# Average loss at step 28000: 3.481165
# Average loss at step 30000: 3.502547
# Nearest to can: may, would, could, must, will, should, might, cannot,
# Nearest to by: during, was, in, under, as, were, when, with,
# Nearest to are: were, have, is, nearer, these, include, sorrows, be,
# Nearest to eight: seven, nine, five, six, four, three, zero, two,
# Nearest to american: british, canadian, austrian, yuan, english, atlantic, unbundling, dutch,
# Nearest to about: wladislaus, rearranging, saline, quoting, affordable, miraculous, scrutiny, assassinate,
# Nearest to as: by, mcgill, competitively, voluntarily, patterson, barada, establishes, is,
# Nearest to four: five, seven, three, eight, six, two, nine, zero,
# Nearest to the: their, its, his, willow, a, adenauer, yaoi, any,
# Nearest to its: their, his, the, her, inwo, lupercalia, freshly, veritas,
# Nearest to during: after, at, in, by, jousting, before, while, within,
# Nearest to so: if, forrest, arrange, mobilization, parties, needed, actually, mansi,
# Nearest to not: still, generally, they, never, who, now, it, there,
# Nearest to world: anthrax, flagellate, u, arthurian, caxton, moderates, separator, effigy,
# Nearest to if: when, perhaps, but, manchurian, is, though, however, so,
# Nearest to over: around, into, lapis, hi, bamako, stevens, entire, teammate,
# Average loss at step 32000: 3.501919
# Average loss at step 34000: 3.493905
# Average loss at step 36000: 3.454651
# Average loss at step 38000: 3.297930
# Average loss at step 40000: 3.428987
# Nearest to can: may, will, could, would, must, should, might, cannot,
# Nearest to by: mitchell, with, mahler, qe, when, tiny, be, was,
# Nearest to are: were, is, have, include, these, be, but, sorrows,
# Nearest to eight: nine, seven, six, four, five, three, zero, one,
# Nearest to american: british, russian, canadian, austrian, japanese, australian, italian, english,
# Nearest to about: wladislaus, rearranging, around, over, spectrometer, adornment, on, assimilated,
# Nearest to as: patterson, chandler, voluntarily, theologiae, zara, resonance, is, by,
# Nearest to four: three, six, seven, eight, five, two, nine, one,
# Nearest to the: this, a, any, their, each, his, its, some,
# Nearest to its: their, his, her, the, freshly, dopant, lupercalia, khufu,
# Nearest to during: at, after, until, within, on, before, while, jousting,
# Nearest to so: parties, forrest, mobilization, if, molecular, burns, haq, mansi,
# Nearest to not: still, they, never, generally, now, you, also, we,
# Nearest to world: flagellate, anthrax, u, caxton, skunk, selina, module, separator,
# Nearest to if: when, is, perhaps, where, gambling, manchurian, however, but,
# Nearest to over: around, into, hi, noi, arcadia, bikini, bamako, about,
# Average loss at step 42000: 3.435101
# Average loss at step 44000: 3.452493
# Average loss at step 46000: 3.452814
# Average loss at step 48000: 3.356452
# Average loss at step 50000: 3.384120
# Nearest to can: could, will, may, must, would, should, might, cannot,
# Nearest to by: through, was, under, during, throughout, landform, haber, with,
# Nearest to are: were, have, is, be, these, sorrows, those, lea,
# Nearest to eight: six, seven, nine, four, five, three, zero, one,
# Nearest to american: british, english, russian, austrian, italian, australian, intercity, yuan,
# Nearest to about: wladislaus, what, rearranging, adornment, spectrometer, irenaeus, bassists, miraculous,
# Nearest to as: similarly, chandler, lucrezia, keyes, became, fulbright, by, jess,
# Nearest to four: six, five, three, seven, eight, nine, two, zero,
# Nearest to the: its, their, his, a, this, chrysostom, many, some,
# Nearest to its: their, his, her, the, freshly, lupercalia, our, guilford,
# Nearest to during: after, at, in, before, within, when, while, from,
# Nearest to so: forrest, if, mobilization, later, regius, something, mckinney, jonson,
# Nearest to not: they, still, never, now, generally, bayesian, able, who,
# Nearest to world: flagellate, anthrax, chisinau, nation, selina, caxton, u, pineapple,
# Nearest to if: when, where, though, although, perhaps, so, however, payne,
# Nearest to over: into, around, stevens, through, rapidly, sponge, happy, fledged,
# Average loss at step 52000: 3.434062
# Average loss at step 54000: 3.428220
# Average loss at step 56000: 3.434463
# Average loss at step 58000: 3.400735
# Average loss at step 60000: 3.395421
# Nearest to can: may, could, will, would, must, should, might, cannot,
# Nearest to by: through, under, with, was, without, landform, be, qe,
# Nearest to are: were, is, have, surfer, include, including, these, doc,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Nearest to american: british, russian, australian, austrian, german, italian, english, canadian,
# Nearest to about: over, rearranging, wladislaus, judicious, bassists, climber, irenaeus, around,
# Nearest to as: lucrezia, similarly, fulbright, voluntarily, barada, disguises, hemorrhagic, chandler,
# Nearest to four: five, eight, seven, six, three, nine, zero, two,
# Nearest to the: its, their, a, this, his, any, kandahar, these,
# Nearest to its: their, his, the, her, freshly, lupercalia, telegrams, tori,
# Nearest to during: after, before, in, within, when, at, since, despite,
# Nearest to so: something, forrest, if, mansi, regius, mobilization, mckinney, thought,
# Nearest to not: still, never, they, generally, desolate, now, compressible, dissipates,
# Nearest to world: flagellate, caxton, largest, anthrax, chisinau, nation, adolescent, bromwich,
# Nearest to if: when, where, though, although, before, however, then, could,
# Nearest to over: around, into, through, about, stevens, within, across, hi,
# Average loss at step 62000: 3.238915
# Average loss at step 64000: 3.256182
# Average loss at step 66000: 3.400768
# Average loss at step 68000: 3.397188
# Average loss at step 70000: 3.358431
# Nearest to can: may, could, would, will, must, might, should, cannot,
# Nearest to by: using, through, mahler, landform, mitchell, be, from, was,
# Nearest to are: were, have, is, these, include, be, including, soong,
# Nearest to eight: nine, seven, six, four, five, zero, three, one,
# Nearest to american: british, italian, german, english, australian, canadian, basel, mexican,
# Nearest to about: over, rearranging, wladislaus, judicious, irenaeus, around, what, isolationist,
# Nearest to as: lucrezia, hemorrhagic, like, sentient, voluntarily, too, mothersbaugh, before,
# Nearest to four: five, six, seven, eight, three, nine, two, zero,
# Nearest to the: its, their, this, a, any, your, some, his,
# Nearest to its: their, her, the, his, our, kanu, dopant, tori,
# Nearest to during: after, before, in, within, until, while, since, throughout,
# Nearest to so: mansi, forrest, regius, if, something, molecular, normalized, later,
# Nearest to not: still, never, generally, now, compressible, they, otherwise, usually,
# Nearest to world: largest, flagellate, anthrax, ii, caxton, skunk, chisinau, u,
# Nearest to if: when, where, though, although, however, before, while, after,
# Nearest to over: around, about, into, through, within, across, sponge, rapidly,
# Average loss at step 72000: 3.373972
# Average loss at step 74000: 3.350267
# Average loss at step 76000: 3.316636
# Average loss at step 78000: 3.357260
# Average loss at step 80000: 3.380109
# Nearest to can: could, may, will, would, must, should, might, cannot,
# Nearest to by: through, unceasing, from, during, landform, was, using, with,
# Nearest to are: were, include, those, have, is, these, although, lichfield,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to american: british, italian, canadian, australian, german, international, russian, hidden,
# Nearest to about: over, convalescence, wladislaus, tecumseh, unethical, spectrometer, rearranging, isolationist,
# Nearest to as: lucrezia, sentient, halides, wyndham, like, positrons, hemorrhagic, amongst,
# Nearest to four: five, six, seven, three, eight, nine, two, zero,
# Nearest to the: its, their, this, his, any, a, those, her,
# Nearest to its: their, his, her, the, our, your, kanu, khufu,
# Nearest to during: after, before, in, when, until, through, despite, within,
# Nearest to so: mansi, forrest, regius, before, later, romney, something, mckinney,
# Nearest to not: still, generally, never, now, they, it, swells, rarely,
# Nearest to world: els, anthrax, flagellate, largest, ii, u, chisinau, cataracts,
# Nearest to if: when, though, where, before, although, after, however, then,
# Nearest to over: around, into, within, across, about, through, hun, happy,
# Average loss at step 82000: 3.406149
# Average loss at step 84000: 3.412034
# Average loss at step 86000: 3.391462
# Average loss at step 88000: 3.352773
# Average loss at step 90000: 3.365314
# Nearest to can: could, may, will, must, should, would, might, cannot,
# Nearest to by: through, using, when, under, with, without, lesbian, during,
# Nearest to are: were, is, include, these, have, although, contain, those,
# Nearest to eight: seven, nine, six, five, four, three, zero, two,
# Nearest to american: british, italian, australian, canadian, french, macbook, german, russian,
# Nearest to about: rearranging, spectrometer, over, tecumseh, unethical, adornment, convalescence, irenaeus,
# Nearest to as: lucrezia, hemorrhagic, photosynthetic, including, bulky, multiplexing, changeover, like,
# Nearest to four: seven, five, three, six, eight, two, nine, zero,
# Nearest to the: its, their, this, his, a, any, whose, our,
# Nearest to its: their, his, her, the, our, your, microinstruction, ornamental,
# Nearest to during: after, before, in, until, when, through, while, at,
# Nearest to so: mansi, regius, before, too, thus, mckinney, then, internetwork,
# Nearest to not: still, never, generally, desolate, bayesian, otherwise, actually, compressible,
# Nearest to world: earth, chisinau, anthrax, adolescent, flagellate, topography, dormitories, chechnya,
# Nearest to if: when, where, though, before, after, since, although, however,
# Nearest to over: around, within, into, off, through, happy, about, across,
# Average loss at step 92000: 3.397052
# Average loss at step 94000: 3.254302
# Average loss at step 96000: 3.356371
# Average loss at step 98000: 3.244466
# Average loss at step 100000: 3.358045
# Nearest to can: could, may, must, will, should, would, might, cannot,
# Nearest to by: including, without, during, using, when, through, under, lesbian,
# Nearest to are: were, have, these, include, those, although, be, while,
# Nearest to eight: seven, nine, six, five, four, three, zero, two,
# Nearest to american: british, canadian, australian, italian, russian, french, revitalize, spinoff,
# Nearest to about: rearranging, subdue, over, approximately, irenaeus, tecumseh, unethical, amen,
# Nearest to as: lucrezia, like, lesser, voluntarily, when, competitively, cura, jess,
# Nearest to four: seven, six, five, eight, three, nine, two, zero,
# Nearest to the: our, his, their, its, a, your, her, some,
# Nearest to its: their, his, our, her, the, khufu, access, your,
# Nearest to during: after, in, before, throughout, until, when, since, at,
# Nearest to so: mansi, thus, mckinney, too, then, regius, forrest, internetwork,
# Nearest to not: never, still, actually, generally, compressible, now, otherwise, they,
# Nearest to world: chisinau, anthrax, venn, dormitories, gunman, earth, pane, nation,
# Nearest to if: when, where, though, before, after, while, although, so,
# Nearest to over: around, within, into, across, happy, off, elven, about,

# %% [markdown]
# ### tSNE可视化

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]窗口大小
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[target]
      labels[i * num_skips + j, 0] = buffer[skip_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'a', 'of']
#     labels: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['anarchism', 'a', 'originated', 'term', 'originated', 'term', 'of', 'as']
#     labels: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  # embedding_lookup()用法: http://blog.csdn.net/u013041398/article/details/60955847
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  print(embed.shape)
  print(softmax_weights.shape)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# (128, 128)
# (50000, 128)

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.153244
# Nearest to its: cretinism, realignment, kenjutsu, insurgency, vinton, rhineland, repositories, mishna,
# Nearest to as: envisaged, phenomenology, licensed, q, ghibellines, yoshida, geoid, dacia,
# Nearest to war: sliced, habib, whiskers, coronae, positioned, crumble, unload, demonstration,
# Nearest to been: bmj, atoms, donner, dct, alfons, luminosity, duodecimal, fervent,
# Nearest to have: hume, islamists, smashed, sourceforge, programmable, rampart, thrax, korn,
# Nearest to not: gian, siege, seraphim, dignitaries, fontsize, gaspar, teen, hesitate,
# Nearest to five: spool, phraseology, conferring, interchangeability, cab, inordinate, occuring, peek,
# Nearest to three: magick, flair, ferromagnetism, fend, papacy, sufferings, heliocentric, cornwallis,
# Nearest to can: loach, outspoken, nicodemus, provers, laughing, pacifists, trypanosoma, dkk,
# Nearest to there: predestination, sandals, unifil, aasen, gotovina, mill, subways, immanence,
# Nearest to first: footnote, maintain, streamlined, telecom, yakuza, prayed, tuba, shunt,
# Nearest to while: failings, offset, clutter, uplifted, straight, injuring, hitter, rocking,
# Nearest to new: glu, ecozone, nepos, dickens, criticizing, cincinnati, armour, spelled,
# Nearest to be: theologies, tri, denotes, socioeconomic, moller, organists, koreans, cynicism,
# Nearest to to: tavistock, nicaragua, lens, hideo, lvaro, necropolis, ishmael, fads,
# Nearest to some: mccormack, prostitution, holmium, elizabethan, reconquest, mathews, animations, profited,
# Average loss at step 2000: 4.365929
# Average loss at step 4000: 3.862651
# Average loss at step 6000: 3.792647
# Average loss at step 8000: 3.691760
# Average loss at step 10000: 3.615549
# Nearest to its: the, their, realignment, his, gutrune, gain, gloucester, iconography,
# Nearest to as: theologically, by, ramakrishna, detached, after, rosette, import, gv,
# Nearest to war: sliced, coronae, whiskers, median, received, comedians, conformation, warms,
# Nearest to been: taggart, smit, atoms, luminosity, by, were, had, undone,
# Nearest to have: had, be, has, were, are, armin, abandoned, austral,
# Nearest to not: they, it, to, mailbox, gian, siege, we, wallenberg,
# Nearest to five: six, eight, four, nine, two, three, seven, zero,
# Nearest to three: four, six, two, five, eight, seven, nine, zero,
# Nearest to can: must, may, should, would, alphege, could, wrestle, will,
# Nearest to there: it, he, they, also, steamboat, trips, often, repellent,
# Nearest to first: prayed, last, same, indra, reset, streamlined, hanseatic, reinforcement,
# Nearest to while: failings, om, cordite, eldridge, under, affairs, gallurese, curlers,
# Nearest to new: sen, criticizing, logging, strapped, ecozone, cubist, twins, firmer,
# Nearest to be: have, heathrow, was, by, make, is, lavishly, exploitation,
# Nearest to to: not, crosley, vertically, chandra, would, pie, hideo, ishmael,
# Nearest to some: many, tbs, originates, profited, reconquest, linkin, these, stung,
# Average loss at step 12000: 3.605459
# Average loss at step 14000: 3.574855
# Average loss at step 16000: 3.407306
# Average loss at step 18000: 3.456323
# Average loss at step 20000: 3.540235
# Nearest to its: their, his, the, her, bannister, gutrune, realignment, gloucester,
# Nearest to as: petals, ramakrishna, when, theologically, envisaged, basalt, detached, zil,
# Nearest to war: median, sliced, antlers, whiskers, coronae, cogito, dekalb, patrols,
# Nearest to been: be, become, were, luminosity, was, intrinsic, had, never,
# Nearest to have: had, be, has, are, were, armin, alberto, functor,
# Nearest to not: they, also, to, we, largely, less, be, it,
# Nearest to five: seven, four, six, eight, three, zero, two, nine,
# Nearest to three: seven, four, six, five, eight, two, nine, zero,
# Nearest to can: may, should, could, would, must, will, might, alphege,
# Nearest to there: it, they, he, which, steamboat, often, repellent, insight,
# Nearest to first: last, third, prayed, same, toward, indra, olympias, rearranged,
# Nearest to while: but, under, although, and, since, cordite, failings, om,
# Nearest to new: sen, alte, ss, baker, cubist, armour, strapped, allows,
# Nearest to be: have, been, is, being, exploitation, by, was, become,
# Nearest to to: would, will, not, may, must, can, fads, codified,
# Nearest to some: many, these, any, all, most, originates, several, ziegfeld,
# Average loss at step 22000: 3.498668
# Average loss at step 24000: 3.489143
# Average loss at step 26000: 3.483300
# Average loss at step 28000: 3.482509
# Average loss at step 30000: 3.505389
# Nearest to its: their, his, the, her, bannister, our, realignment, s,
# Nearest to as: by, theologically, rosette, resonant, storm, ramakrishna, basalt, or,
# Nearest to war: median, obtaining, antlers, dekalb, sliced, aeneas, cogito, nunavut,
# Nearest to been: become, be, were, was, luminosity, already, had, smit,
# Nearest to have: had, has, are, be, were, having, do, armin,
# Nearest to not: they, it, largely, you, still, generally, we, also,
# Nearest to five: four, eight, three, six, seven, nine, zero, two,
# Nearest to three: four, five, six, eight, seven, two, nine, zero,
# Nearest to can: may, would, could, will, should, must, cannot, might,
# Nearest to there: they, it, he, often, still, now, usually, which,
# Nearest to first: last, second, same, next, third, prayed, rearranged, toward,
# Nearest to while: although, but, where, however, cordite, when, since, midwest,
# Nearest to new: sen, different, alte, ss, cubist, logging, melody, projectiles,
# Nearest to be: is, been, have, become, are, was, were, modernize,
# Nearest to to: would, can, will, must, crosley, fledged, may, could,
# Nearest to some: many, these, all, several, any, their, various, other,
# Average loss at step 32000: 3.502231
# Average loss at step 34000: 3.495448
# Average loss at step 36000: 3.455248
# Average loss at step 38000: 3.301577
# Average loss at step 40000: 3.427880
# Nearest to its: their, his, the, her, bannister, centro, gloucester, realignment,
# Nearest to as: when, by, basalt, kingfisher, detached, storm, rosette, almoravids,
# Nearest to war: median, obtaining, antlers, cogito, orphan, dekalb, sliced, factbook,
# Nearest to been: become, was, be, already, luminosity, were, suffered, had,
# Nearest to have: had, has, were, be, are, include, kitchen, vanes,
# Nearest to not: they, largely, it, still, generally, now, usually, less,
# Nearest to five: seven, six, four, eight, three, two, nine, zero,
# Nearest to three: two, four, five, six, seven, eight, nine, one,
# Nearest to can: may, could, will, would, must, should, cannot, might,
# Nearest to there: they, it, he, usually, still, often, which, now,
# Nearest to first: last, second, next, same, third, tenn, prayed, qa,
# Nearest to while: although, when, but, however, though, where, vivisection, slaying,
# Nearest to new: sen, guido, reactance, logging, cubist, comparison, armour, ozzfest,
# Nearest to be: have, been, are, become, was, is, being, by,
# Nearest to to: will, could, would, physica, must, endemic, can, codified,
# Nearest to some: many, these, any, several, various, this, all, certain,
# Average loss at step 42000: 3.436379
# Average loss at step 44000: 3.451722
# Average loss at step 46000: 3.455569
# Average loss at step 48000: 3.351497
# Average loss at step 50000: 3.382556
# Nearest to its: their, his, the, her, bestseller, our, obadiah, designates,
# Nearest to as: import, became, envisaged, when, ramakrishna, storm, batasuna, rosette,
# Nearest to war: median, obtaining, factbook, cogito, antlers, orphan, dekalb, oneworld,
# Nearest to been: become, already, was, be, luminosity, suffered, were, pistol,
# Nearest to have: had, has, were, are, be, having, denny, reworked,
# Nearest to not: they, now, generally, usually, largely, mysteriously, never, less,
# Nearest to five: six, four, seven, eight, three, zero, nine, two,
# Nearest to three: six, seven, four, eight, five, nine, two, zero,
# Nearest to can: may, could, would, will, must, should, cannot, might,
# Nearest to there: they, it, he, still, she, now, usually, often,
# Nearest to first: last, second, next, third, final, present, same, standby,
# Nearest to while: although, when, but, however, where, for, though, including,
# Nearest to new: armour, sen, reactance, vt, melody, ss, kournikova, second,
# Nearest to be: have, become, being, been, were, is, was, are,
# Nearest to to: would, could, will, can, may, fledged, yo, gravely,
# Nearest to some: many, these, several, various, any, both, all, the,
# Average loss at step 52000: 3.434896
# Average loss at step 54000: 3.427428
# Average loss at step 56000: 3.440122
# Average loss at step 58000: 3.399659
# Average loss at step 60000: 3.394801
# Nearest to its: their, his, the, her, bestseller, obadiah, our, abiding,
# Nearest to as: envisaged, when, basalt, import, rosette, drowns, ramakrishna, theologically,
# Nearest to war: median, obtaining, factbook, antlers, orphan, cogito, abodes, imbalances,
# Nearest to been: become, be, was, luminosity, already, were, suffered, had,
# Nearest to have: had, has, were, are, having, include, be, vanes,
# Nearest to not: still, usually, now, they, never, filter, it, t,
# Nearest to five: four, six, three, seven, eight, nine, zero, two,
# Nearest to three: five, four, seven, eight, six, two, nine, one,
# Nearest to can: may, could, would, will, must, should, cannot, might,
# Nearest to there: they, it, this, he, still, she, now, often,
# Nearest to first: last, second, next, third, final, same, only, present,
# Nearest to while: although, when, after, before, including, were, though, if,
# Nearest to new: different, reactance, armour, cubist, lcc, aggregation, zeit, sen,
# Nearest to be: been, is, was, become, have, being, seem, scytale,
# Nearest to to: would, not, endemic, blockbusters, chandra, crosley, may, gee,
# Nearest to some: many, these, several, any, various, most, the, different,
# Average loss at step 62000: 3.245607
# Average loss at step 64000: 3.259801
# Average loss at step 66000: 3.408588
# Average loss at step 68000: 3.393320
# Average loss at step 70000: 3.361428
# Nearest to its: their, his, the, her, bestseller, bannister, obadiah, designates,
# Nearest to as: produce, is, using, zil, daylights, when, solitaire, drowns,
# Nearest to war: obtaining, median, factbook, orphan, antlers, imbalances, caroli, azeotrope,
# Nearest to been: become, be, was, already, were, suffered, had, luminosity,
# Nearest to have: had, has, were, are, include, having, be, contain,
# Nearest to not: now, still, generally, usually, never, largely, it, always,
# Nearest to five: four, eight, six, seven, three, nine, zero, two,
# Nearest to three: two, four, five, six, seven, eight, nine, zero,
# Nearest to can: may, could, would, will, must, should, cannot, might,
# Nearest to there: they, it, still, he, we, usually, often, she,
# Nearest to first: second, last, next, third, same, final, original, present,
# Nearest to while: although, though, when, including, if, after, however, and,
# Nearest to new: reactance, cubist, different, armour, lcc, malay, sen, aggregation,
# Nearest to be: been, is, become, being, have, were, avoid, by,
# Nearest to to: must, can, would, could, will, might, chandra, crosley,
# Nearest to some: many, several, these, various, all, any, their, most,
# Average loss at step 72000: 3.379402
# Average loss at step 74000: 3.349237
# Average loss at step 76000: 3.320108
# Average loss at step 78000: 3.351014
# Average loss at step 80000: 3.379383
# Nearest to its: their, his, her, the, your, bannister, drawings, our,
# Nearest to as: daylights, before, hyatt, including, envisaged, when, vagantes, import,
# Nearest to war: obtaining, factbook, median, wars, spyware, picking, antlers, imbalances,
# Nearest to been: become, be, suffered, were, already, was, candu, had,
# Nearest to have: had, has, are, were, having, include, be, vanes,
# Nearest to not: still, generally, now, always, usually, never, often, it,
# Nearest to five: six, four, seven, eight, three, nine, zero, two,
# Nearest to three: six, seven, five, eight, four, two, nine, zero,
# Nearest to can: will, could, may, must, would, should, cannot, might,
# Nearest to there: they, it, he, still, usually, she, often, we,
# Nearest to first: last, second, next, third, final, fourth, same, only,
# Nearest to while: although, though, after, when, before, including, however, but,
# Nearest to new: different, desiderius, old, lcc, asymmetry, cubist, modern, mantle,
# Nearest to be: been, being, become, have, is, was, fashioning, seem,
# Nearest to to: would, can, chandra, must, gee, could, may, crosley,
# Nearest to some: many, several, various, all, these, most, any, certain,
# Average loss at step 82000: 3.410429
# Average loss at step 84000: 3.410746
# Average loss at step 86000: 3.392271
# Average loss at step 88000: 3.352436
# Average loss at step 90000: 3.365764
# Nearest to its: their, his, her, the, your, our, whose, gujarat,
# Nearest to as: including, daylights, streamlining, speyer, zil, terran, when, dist,
# Nearest to war: obtaining, median, factbook, wars, caroli, spouses, abodes, alder,
# Nearest to been: become, be, already, was, suffered, luminosity, pistol, previously,
# Nearest to have: had, has, are, were, having, include, be, reworked,
# Nearest to not: still, now, generally, never, nor, t, they, also,
# Nearest to five: eight, six, seven, four, three, nine, two, zero,
# Nearest to three: two, five, four, seven, eight, six, nine, zero,
# Nearest to can: could, will, may, would, should, must, cannot, might,
# Nearest to there: they, it, he, usually, still, we, she, generally,
# Nearest to first: last, second, next, final, third, same, original, earliest,
# Nearest to while: although, when, before, after, though, during, were, and,
# Nearest to new: old, different, refractory, modern, guido, attestation, sen, skeptics,
# Nearest to be: been, become, being, was, is, have, seem, lavishly,
# Nearest to to: would, chandra, will, towards, hideo, could, must, should,
# Nearest to some: many, several, all, these, most, various, certain, any,
# Average loss at step 92000: 3.398723
# Average loss at step 94000: 3.253660
# Average loss at step 96000: 3.362105
# Average loss at step 98000: 3.244289
# Average loss at step 100000: 3.357625
# Nearest to its: their, his, her, the, gujarat, yearly, our, whose,
# Nearest to as: when, including, daylights, zug, envisaged, kingfisher, obesity, interwar,
# Nearest to war: obtaining, factbook, wars, median, caroli, spouses, imbalances, bai,
# Nearest to been: become, be, already, suffered, was, were, recently, luminosity,
# Nearest to have: had, has, are, were, include, be, contain, having,
# Nearest to not: never, still, now, generally, nor, usually, almost, actually,
# Nearest to five: six, seven, four, eight, three, two, nine, zero,
# Nearest to three: six, five, four, two, seven, eight, nine, zero,
# Nearest to can: may, could, will, must, would, should, cannot, might,
# Nearest to there: they, he, it, still, often, usually, now, sometimes,
# Nearest to first: last, second, next, third, final, fourth, same, original,
# Nearest to while: although, when, though, before, but, after, however, and,
# Nearest to new: different, reactance, comparison, armour, logging, cubist, asymmetry, guido,
# Nearest to be: been, become, have, is, being, are, produce, lavishly,
# Nearest to to: could, would, will, must, chandra, can, should, towards,
# Nearest to some: many, several, these, any, various, all, certain, most,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
 # num_skips = 2 * bag_window
  batch = np.ndarray(shape=(batch_size, 2 * bag_window), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * bag_window + 1 # [ bag_window label bag_window ]窗口大小
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
#  print(batch_size, num_skips)
  for i in range(batch_size):
    target = bag_window  # target label at the center of the buffer
    targets_to_avoid = [ bag_window ]
    for j in range(2 * bag_window):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      #print(reverse_dictionary[buffer[target]])
      batch[i, j] = buffer[target]
    labels[i, 0] = buffer[bag_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:10]])

for bag_window in [1, 2]:
    data_index = 0 
    batch, labels = generate_batch(batch_size=8, bag_window=bag_window)
    print('\nwith bag_window = %d:' % (bag_window))
    print('    batch:', [[reverse_dictionary[i] for i in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['of', 'a'], ['term', 'abuse'], ['first', 'of'], ['used', 'abuse'], ['against', 'first']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with bag_window = 2:
#     batch: [['originated', 'term', 'anarchism', 'a'], ['originated', 'of', 'term', 'as'], ['as', 'of', 'abuse', 'a'], ['a', 'first', 'abuse', 'term'], ['term', 'first', 'used', 'of'], ['abuse', 'of', 'used', 'against'], ['first', 'against', 'abuse', 'early'], ['early', 'working', 'used', 'first']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
batch_size = 1
embedding_size = 128 # Dimension of the embedding vector.
# skip_window = 1 # How many words to consider left and right.
bag_window = 1 # How many words to consider left and right.
# num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, num_skips])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  # embedding_lookup()用法: http://blog.csdn.net/u013041398/article/details/60955847
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  print(embed.shape)
  print(softmax_weights.shape)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embed, 1),
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(num_skips * embeddings), 1, keep_dims=True))
  normalized_embeddings = num_skips * embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# (128, 2, 128)
# (50000, 128)

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.499818
# Nearest to they: revamped, confines, afro, necessity, inclusion, disconnect, pregnant, cogency,
# Nearest to can: heschel, tiger, halpin, dressed, airspeed, brindisi, stoughton, folkloric,
# Nearest to seven: thistle, gumby, aragon, gf, lamented, stopping, dugout, absolutely,
# Nearest to one: standards, chinese, clinch, mascarenes, compensates, trotskyist, oftentimes, refurbished,
# Nearest to most: me, physiocrats, intentions, supermarket, na, university, degree, calligraphy,
# Nearest to d: cousins, franco, federko, concessions, disestablishment, ppm, homeopaths, arrian,
# Nearest to three: heroine, obelix, boom, fujiwara, bitrate, swanson, dress, nanotech,
# Nearest to its: batted, conferred, corgi, heretofore, bulldogs, rum, hippocratic, inflow,
# Nearest to four: clarion, caviar, quantrill, scat, mildred, accumulating, imposition, voor,
# Nearest to and: henze, symbolics, inspections, yn, dispensationalism, neorealism, klein, glitter,
# Nearest to may: depositing, alcoholism, kenobi, prepubescent, password, indic, af, sheng,
# Nearest to from: rijndael, lecturers, errico, hurst, resident, nikaya, ecoregion, breeds,
# Nearest to all: georgetown, atat, shrubs, inquiring, juneau, karnataka, sartre, amusing,
# Nearest to but: neurotransmitter, campo, bijection, behaviorist, gheorghe, jmp, sheath, denouncing,
# Nearest to use: floss, caleb, spacewalks, redeemed, petersburg, dependencies, giza, stoics,
# Nearest to time: dissension, accompanies, permutation, daedalus, contrasting, rapier, hydrosphere, talent,
# Average loss at step 2000: 4.096642
# Average loss at step 4000: 3.563972
# Average loss at step 6000: 3.388546
# Average loss at step 8000: 3.242462
# Average loss at step 10000: 3.178552
# Nearest to they: he, we, there, she, then, who, you, it,
# Nearest to can: may, could, would, should, will, must, might, to,
# Nearest to seven: eight, six, nine, four, five, three, zero, two,
# Nearest to one: two, four, eight, six, seven, three, erased, radians,
# Nearest to most: some, nicaea, more, degree, me, bello, jos, use,
# Nearest to d: b, federko, nantucket, strikingly, hinders, polly, musicologists, mirrored,
# Nearest to three: four, six, five, seven, eight, zero, two, nine,
# Nearest to its: their, his, the, separable, conceptions, staccato, giotto, conferred,
# Nearest to four: eight, seven, six, five, three, nine, zero, two,
# Nearest to and: or, ect, bainbridge, lothair, trilemma, generated, satellites, yak,
# Nearest to may: can, would, depositing, should, could, might, will, shall,
# Nearest to from: through, in, into, manually, by, compiles, powerhouse, after,
# Nearest to all: many, cassel, these, waived, some, rectal, tempe, microorganism,
# Nearest to but: however, that, terminology, though, plausibility, musique, flammable, did,
# Nearest to use: petersburg, perceptible, oceanographic, redeemed, become, stature, rise, spacewalks,
# Nearest to time: fact, intention, fad, analogies, saw, gilbert, radios, permutation,
# Average loss at step 12000: 3.205019
# Average loss at step 14000: 3.152920
# Average loss at step 16000: 3.174587
# Average loss at step 18000: 3.130139
# Average loss at step 20000: 2.988410
# Nearest to they: we, there, he, you, she, these, who, it,
# Nearest to can: may, could, will, would, must, should, might, cannot,
# Nearest to seven: six, eight, five, nine, four, three, zero, two,
# Nearest to one: eight, two, six, five, four, seven, locust, nine,
# Nearest to most: more, many, some, various, very, several, less, jos,
# Nearest to d: b, brod, federko, hop, eradicating, mirrored, strikingly, reconcile,
# Nearest to three: four, five, seven, six, eight, two, zero, nine,
# Nearest to its: their, his, the, her, staccato, lindh, separable, our,
# Nearest to four: five, seven, eight, six, three, nine, zero, two,
# Nearest to and: or, but, who, vs, formalize, satellites, rosenzweig, corticosteroids,
# Nearest to may: can, would, will, could, should, must, might, shall,
# Nearest to from: through, into, alias, manually, during, disenchantment, in, between,
# Nearest to all: both, many, some, documenting, these, overly, cassel, gibbs,
# Nearest to but: however, and, which, prepubescent, see, while, he, subverting,
# Nearest to use: pays, perceptible, rise, stature, dendrite, thor, barrister, employment,
# Nearest to time: fact, saw, intention, nicotine, scenarios, predicted, sanctuaries, vater,
# Average loss at step 22000: 3.069396
# Average loss at step 24000: 3.037743
# Average loss at step 26000: 3.008965
# Average loss at step 28000: 3.031108
# Average loss at step 30000: 2.999874
# Nearest to they: we, there, he, you, she, it, esq, who,
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Nearest to seven: eight, six, nine, four, five, three, zero, two,
# Nearest to one: two, six, five, four, seven, three, nine, glastonbury,
# Nearest to most: more, some, many, buildup, particularly, especially, use, lavon,
# Nearest to d: b, et, eradicating, reconcile, brod, hop, l, strikingly,
# Nearest to three: five, four, six, two, seven, eight, nine, zero,
# Nearest to its: their, his, her, the, staccato, lindh, separable, our,
# Nearest to four: six, five, seven, eight, three, nine, two, zero,
# Nearest to and: or, but, than, however, like, watertown, rosenzweig, satellites,
# Nearest to may: can, would, will, could, should, might, must, cannot,
# Nearest to from: through, into, manually, during, lecturers, in, despite, after,
# Nearest to all: both, each, any, some, many, those, these, every,
# Nearest to but: however, and, although, plausibility, see, which, marking, insurer,
# Nearest to use: popularity, most, sense, rise, support, stature, form, perceptible,
# Nearest to time: intention, saw, fact, case, nicotine, thing, way, calcite,
# Average loss at step 32000: 2.828229
# Average loss at step 34000: 2.951276
# Average loss at step 36000: 2.951349
# Average loss at step 38000: 2.940893
# Average loss at step 40000: 2.930281
# Nearest to they: we, there, you, he, she, soon, who, it,
# Nearest to can: may, could, will, must, would, might, should, cannot,
# Nearest to seven: eight, six, five, four, nine, three, zero, two,
# Nearest to one: two, seven, six, eight, unranked, three, four, five,
# Nearest to most: some, more, many, less, particularly, especially, bingo, very,
# Nearest to d: b, eradicating, pandavas, j, l, brod, federko, unopposed,
# Nearest to three: six, four, seven, five, two, eight, zero, nine,
# Nearest to its: their, his, the, her, our, separable, staccato, alerting,
# Nearest to four: five, six, seven, three, eight, nine, zero, two,
# Nearest to and: or, while, but, vs, megafauna, gateless, collaborated, billiard,
# Nearest to may: can, would, will, might, must, should, could, cannot,
# Nearest to from: through, into, during, before, between, across, within, by,
# Nearest to all: both, every, any, many, some, sandhi, various, each,
# Nearest to but: however, although, and, while, diagnosing, than, hoarding, expressed,
# Nearest to use: because, source, popularity, form, support, perceptible, sense, cause,
# Nearest to time: intention, fact, nicotine, hades, thing, calcite, possession, saw,
# Average loss at step 42000: 2.953529
# Average loss at step 44000: 2.958562
# Average loss at step 46000: 2.913020
# Average loss at step 48000: 2.869785
# Average loss at step 50000: 2.840952
# Nearest to they: we, there, you, he, she, it, soon, esq,
# Nearest to can: may, could, must, will, might, would, should, cannot,
# Nearest to seven: eight, six, four, five, nine, three, zero, two,
# Nearest to one: four, two, seven, six, eight, zero, nine, three,
# Nearest to most: more, some, many, less, particularly, especially, several, reina,
# Nearest to d: b, meister, luxuriant, humanist, antibody, and, federko, gordon,
# Nearest to three: four, five, six, seven, two, eight, zero, nine,
# Nearest to its: their, his, her, the, our, staccato, reiterated, alerting,
# Nearest to four: seven, six, five, three, eight, two, nine, zero,
# Nearest to and: or, while, but, vibrating, including, corticosteroids, oxycoccus, townspeople,
# Nearest to may: can, should, must, will, could, might, would, cannot,
# Nearest to from: through, into, during, across, in, despite, lecturers, within,
# Nearest to all: both, several, many, every, various, these, some, those,
# Nearest to but: however, although, while, though, and, do, assists, complemented,
# Nearest to use: increase, support, sense, cause, threaten, employment, form, malabo,
# Nearest to time: nicotine, fact, thing, intention, hades, life, year, idea,
# Average loss at step 52000: 2.891050
# Average loss at step 54000: 2.864245
# Average loss at step 56000: 2.860331
# Average loss at step 58000: 2.747478
# Average loss at step 60000: 2.826416
# Nearest to they: we, you, he, there, she, it, who, soon,
# Nearest to can: could, may, will, must, should, might, would, cannot,
# Nearest to seven: five, eight, six, four, nine, three, zero, two,
# Nearest to one: two, seven, four, six, five, eight, three, nine,
# Nearest to most: more, particularly, less, some, especially, many, quite, precession,
# Nearest to d: b, j, eradicating, l, o, pee, bugtraq, h,
# Nearest to three: four, two, five, seven, six, eight, zero, nine,
# Nearest to its: their, his, the, her, your, our, alerting, giotto,
# Nearest to four: five, seven, six, eight, three, two, nine, zero,
# Nearest to and: or, but, while, although, vs, including, like, rosenzweig,
# Nearest to may: can, should, could, must, will, might, would, cannot,
# Nearest to from: through, into, lecturers, in, after, during, across, manually,
# Nearest to all: every, many, both, various, any, several, these, certain,
# Nearest to but: however, although, and, though, while, raging, hci, complemented,
# Nearest to use: form, support, cause, demand, sense, increase, most, pays,
# Nearest to time: thing, possession, fact, intention, length, hades, day, period,
# Average loss at step 62000: 2.828506
# Average loss at step 64000: 2.776362
# Average loss at step 66000: 2.758456
# Average loss at step 68000: 2.713815
# Average loss at step 70000: 2.785138
# Nearest to they: we, you, he, there, she, it, soon, these,
# Nearest to can: should, could, may, must, will, might, cannot, would,
# Nearest to seven: five, eight, six, nine, three, four, zero, two,
# Nearest to one: two, eight, seven, three, four, five, six, nine,
# Nearest to most: more, many, less, some, particularly, reconstructionist, especially, dinneen,
# Nearest to d: b, eradicating, smoothed, pee, meru, meister, rdoba, antibody,
# Nearest to three: seven, four, five, six, two, eight, nine, zero,
# Nearest to its: their, his, the, her, our, lindh, whose, alerting,
# Nearest to four: six, eight, three, five, seven, two, nine, zero,
# Nearest to and: or, but, vs, although, while, including, categorically, corticosteroids,
# Nearest to may: should, can, must, could, will, might, would, cannot,
# Nearest to from: through, into, lecturers, under, across, in, within, during,
# Nearest to all: both, various, many, certain, every, several, these, putnam,
# Nearest to but: however, although, though, and, while, that, assists, remained,
# Nearest to use: cause, believe, form, sense, list, demand, popularity, manage,
# Nearest to time: possession, length, fact, thing, intention, lobes, escoffier, revered,
# Average loss at step 72000: 2.795310
# Average loss at step 74000: 2.644587
# Average loss at step 76000: 2.800565
# Average loss at step 78000: 2.818535
# Average loss at step 80000: 2.785329
# Nearest to they: we, you, he, there, she, i, soon, it,
# Nearest to can: could, may, should, will, must, would, might, cannot,
# Nearest to seven: eight, six, nine, five, four, zero, three, two,
# Nearest to one: seven, two, six, eight, four, nine, three, five,
# Nearest to most: more, many, less, some, particularly, reconstructionist, dinneen, several,
# Nearest to d: b, eradicating, c, ungrammatical, bugtraq, pee, imo, abidjan,
# Nearest to three: four, six, two, five, seven, eight, nine, zero,
# Nearest to its: their, his, the, her, whose, our, alerting, kinross,
# Nearest to four: five, six, seven, three, eight, two, nine, zero,
# Nearest to and: or, but, including, sonorants, though, although, corticosteroids, thurber,
# Nearest to may: can, could, should, might, would, must, will, cannot,
# Nearest to from: across, through, into, lecturers, within, including, before, under,
# Nearest to all: both, many, various, any, every, mined, several, putnam,
# Nearest to but: however, although, though, and, which, assists, parcham, remained,
# Nearest to use: cause, sense, list, because, form, popularity, possibility, threaten,
# Nearest to time: day, possession, thing, storytelling, year, period, month, idea,
# Average loss at step 82000: 2.665759
# Average loss at step 84000: 2.766417
# Average loss at step 86000: 2.733663
# Average loss at step 88000: 2.753377
# Average loss at step 90000: 2.736750
# Nearest to they: we, you, he, there, she, i, it, who,
# Nearest to can: should, could, must, might, will, may, would, cannot,
# Nearest to seven: eight, six, nine, five, four, zero, three, two,
# Nearest to one: two, four, six, eight, seven, five, three, nine,
# Nearest to most: more, many, some, less, particularly, especially, reconstructionist, buildup,
# Nearest to d: b, j, eradicating, g, c, loom, ungrammatical, haq,
# Nearest to three: four, two, six, five, seven, eight, nine, zero,
# Nearest to its: their, his, whose, the, her, staccato, lindh, our,
# Nearest to four: six, five, seven, eight, three, two, nine, zero,
# Nearest to and: or, including, although, but, jute, vs, faceted, nutty,
# Nearest to may: should, could, can, might, must, would, will, cannot,
# Nearest to from: through, across, including, into, in, via, lecturers, during,
# Nearest to all: both, various, many, any, some, certain, every, several,
# Nearest to but: however, although, though, assists, see, and, zn, bridging,
# Nearest to use: cause, manage, need, increase, form, because, sense, threaten,
# Nearest to time: vater, day, possession, storytelling, era, year, tout, cade,
# Average loss at step 92000: 2.677632
# Average loss at step 94000: 2.724622
# Average loss at step 96000: 2.701981
# Average loss at step 98000: 2.364569
# Average loss at step 100000: 2.395377
# Nearest to they: we, he, there, you, she, i, soon, it,
# Nearest to can: will, must, could, should, cannot, might, would, may,
# Nearest to seven: six, eight, nine, five, four, three, zero, two,
# Nearest to one: two, six, seven, three, five, four, nine, locust,
# Nearest to most: more, less, particularly, especially, dinneen, many, buildup, some,
# Nearest to d: b, smoothed, eradicating, federko, pee, antibody, ungrammatical, forman,
# Nearest to three: four, five, six, two, seven, eight, nine, zero,
# Nearest to its: their, his, her, whose, the, staccato, kinross, our,
# Nearest to four: five, six, seven, three, eight, nine, zero, two,
# Nearest to and: or, but, including, rosenzweig, though, who, nor, watertown,
# Nearest to may: should, must, might, could, can, would, will, cannot,
# Nearest to from: through, across, via, including, lecturers, into, despite, in,
# Nearest to all: both, various, many, several, some, every, any, these,
# Nearest to but: however, although, though, and, while, despite, remained, did,
# Nearest to use: cause, form, because, likelihood, kuiper, list, possibility, consist,
# Nearest to time: reign, possession, kind, period, era, vater, thing, promise,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
